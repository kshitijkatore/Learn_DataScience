# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
tips =sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter Plot of Total Bill ve Tip")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Total Bill ve Tip')

# %%
# Line Plot

sns.lineplot(x='size',y='total_bill',data =tips)
plt.title("Line Plot Total_Bill Vs Size")
# Out:
# Text(0.5, 1.0, 'Line Plot Total_Bill Vs Size')

# %%
# Categorical Plots

sns.barplot(x='day',y='total_bill', data=tips)
plt.title("Bar plot of Total_bill Vs Day")
# Out:
# Text(0.5, 1.0, 'Bar plot of Total_bill Vs Day')

# %%
## Box Plot
sns.boxenplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Voilen Plot
sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Histograms

sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE Plot
sns.kdeplot(tips['total_bill'],shade=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_13256\2771851424.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'],shade=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pairplot
sns.pairplot(tips)

# %%
## Heatmap
corr =tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df = pd.read_csv('sales.csv')
sales_df
# Out:
#     SaleID  Product Region SalesPerson   Amount        Date
# 0        1   Laptop  South       Frank  1129.58  2023-01-01
# 1        2    Phone  North     Charlie   630.00  2023-01-16
# 2        3   Tablet   East        Jack   428.12  2023-01-31
# 3        4   Laptop  North       Alice  1360.84  2023-02-15
# 4        5    Phone  North        Jack   870.96  2023-03-02
# 5        6  Monitor   West       Frank  1410.26  2023-03-17
# 6        7   Laptop  South       Grace   727.90  2023-04-01
# 7        8    Phone   West        Jack   239.40  2023-04-16
# 8        9   Tablet  South       Grace   470.17  2023-05-01
# 9       10    Phone   West         Ian   414.57  2023-05-16
# 10      11    Phone  North       Alice   781.42  2023-05-31
# 11      12   Tablet   East     Charlie   566.21  2023-06-15
# 12      13   Tablet   East       Helen   576.56  2023-06-30
# 13      14    Phone   West       David   742.15  2023-07-15
# 14      15   Tablet  South     Charlie   509.13  2023-07-30
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SaleID       20 non-null     int64
#  1   Product      20 non-null     object
#  2   Region       20 non-null     object
#  3   SalesPerson  20 non-null     object
#  4   Amount       20 non-null     float64
#  5   Date         20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
#3 Plot Total sales by product

plt.figure(figsize=(10,6))

sns.barplot(x='Product',y='Amount',data = sales_df,estimator=sum)
plt.title("Total Sales By Product")
# Out:
# Text(0.5, 1.0, 'Total Sales By Product')
